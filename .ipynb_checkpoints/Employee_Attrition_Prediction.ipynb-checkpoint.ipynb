# %%
print(" Employee Attrition Prediction")

print("🚀 Build a Predictive Model for Employee Attrition")

print("👨‍💻 Author: Shubham More")
# Out:
#  Employee Attrition Prediction
# 🚀 Build a Predictive Model for Employee Attrition
# 👨‍💻 Author: Shubham More

# %%
# Import Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read Dataset
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Check Duplicate Records

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Unique Values in Each Column

df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.boxplot(df['MonthlyIncome'])

plt.title("Boxplot of Monthly Income")
plt.ylabel("Monthly Income")

plt.show()

# %%
# Barplot 1: Employee Attrition (target variable)

plt.figure(figsize=(6,4))
df['Attrition'].value_counts().plot(kind='bar', color=['steelblue','tomato'])
plt.title("Employee Attrition")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Barplot 2: Gender Distribution

plt.figure(figsize=(6,4))
df['Gender'].value_counts().plot(kind='bar', color=['skyblue','orange'])

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
# Barplot 3: Department Distribution

plt.figure(figsize=(7,4))
df['Department'].value_counts().plot(kind='bar', color='green')

plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Count")
plt.xticks(rotation=15)
plt.show()

# %%
# Barplot 4: Business Travel

plt.figure(figsize=(7,4))
df['BusinessTravel'].value_counts().plot(kind='bar', color='brown')

plt.title("Business Travel")
plt.xlabel("Business Travel")
plt.ylabel("Count")
plt.show()

# %%
# Barplot 5: OverTime

plt.figure(figsize=(6,4))
df['OverTime'].value_counts().plot(kind='bar', color=['blue','red'])

plt.title("OverTime")
plt.xlabel("OverTime")
plt.ylabel("Count")
plt.show()

# %%
# Barplot 6: Job Satisfaction

plt.figure(figsize=(6,4))
df['JobSatisfaction'].value_counts().sort_index().plot(kind='bar', color='gold')

plt.title("Job Satisfaction")
plt.xlabel("Job Satisfaction Level")
plt.ylabel("Count")
plt.show()

# %%
# Barplot 7: Job Role

plt.figure(figsize=(10,5))
df['JobRole'].value_counts().plot(kind='bar', color='purple')

plt.title("Employees by Job Role")
plt.xlabel("Job Role")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Barplot 8: Education Field

plt.figure(figsize=(8,4))
df['EducationField'].value_counts().plot(kind='bar', color='teal')

plt.title("Education Field")
plt.xlabel("Education Field")
plt.ylabel("Count")
plt.xticks(rotation=30)
plt.show()
